# %%
import numpy as np
from astropy import units as u
from astropy.coordinates import Angle
import os 
import folium
from folium import plugins
import IFR_subroutines as subs
import importlib as imp
import matplotlib.pyplot as plt

# %%
##########################
# Files used:
##########################

potential_good = '../DATA/gps_pos_default_v2.snx'
#potential_try = '../DATA/potential_stations_350_DRAO' #create this!
actual_good = '../DATA/albus_good_stations_DRAO_CHIME_test_Aug_2017'

DRAO_data_Aug2017 = '../DATA/albus_report_parallel_RI_G03_DRAO_CHIME_test_Aug_2017'
DRAO_data_Jan2021 = '../DATA/albus_report_parallel_RI_G03_DRAO_CHIME_test_Jan_2021'
Allenby_data_Jan2021 = '../DATA/albus_report_parallel_RI_G03_Allenby_CHIME_test_Jan_2021'


lon_allenby = -120.525
lat_allenby = 49.419

# %%
imp.reload(subs)

all_stn, all_lon, all_lat = subs.read_master_station_list(potential_good)
print('Number of stations in master list: ',len(all_stn))
#for i in range(0,len(all_stn)):
#    print(all_stn[i],all_lon[i],all_lat[i])
print('')
good_stn, good_lon, good_lat = subs.read_stations_used(actual_good,all_stn,all_lon,all_lat)
print('Number of stations used by ALBUS: ',len(good_stn))
print('')
#bad_stn, bad_lon, bad_lat = subs.read_stations_failed(potential_try,good_stn,all_stn,all_lon,all_lat,excl_stn)
#print('Number of stations failed in ALBUS: ',len(bad_stn))
#print(bad_stn)
# Out:
# Number of stations in master list:  830
#
# Number of stations used by ALBUS:  47

# %%
m = folium.Map(location=[49.3, -119.6],tiles="Stamen Terrain",zoom_start=5)
all_pts = len(all_lon)
good_pts = len(good_lon)
#bad_pts = len(bad_lon)

#for i in range(0,all_pts):
#    folium.Marker(location=[all_lat[i],all_lon[i]],popup=all_stn[i],
#                       icon=folium.Icon(icon='glyphicon-map-marker',color='white',icon_size=0.5)).add_to(m)

#for i in range(0,bad_pts):
#    folium.Marker(location=[bad_lat[i],bad_lon[i]],popup=bad_stn[i],
#                       icon=folium.Icon(icon='glyphicon-remove-circle',color='red')).add_to(m)
#for i in range(0,good_pts):
#    folium.Marker(location=[good_lat[i],good_lon[i]],popup=good_stn[i], 
#                       icon=folium.Icon(icon='glyphicon-map-marker',color='blue',icon_size=(10,10))).add_to(m)
for i in range(0,good_pts):
    folium.Marker(location=[good_lat[i],good_lon[i]],popup=good_stn[i],
                  icon=folium.Icon(icon='glyphicon-map-marker',color='blue')).add_to(m)

folium.Marker(location=[lat_allenby,lon_allenby],popup='Allenby',
                  icon=folium.Icon(icon='glyphicon-map-marker',color='purple')).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
print(good_lon)
# Out:
# [-123.48738889 -119.68263889 -123.45111111 -119.625      -123.70411111
#  -122.14183333 -116.262      -122.75830556 -122.23577778 -117.70994444
#  -122.2565     -123.21991667 -118.14780556 -116.97966667 -122.76055556
#  -115.84241667 -121.95555556 -117.66455556 -121.78805556 -118.55813889
#  -119.15861111 -121.79705556 -119.5515     -119.16786111 -122.20475
#  -117.19308333 -120.79230556 -123.49433333 -119.413      -122.34502778
#  -121.38827778 -117.50255556 -122.31513889 -122.66738889 -122.60572222
#  -122.77586111 -122.47894444 -121.74927778 -117.63169444 -119.79083333
#  -117.90325    -121.06752778 -122.68558333 -123.00758333 -116.2875
#  -120.28466667 -117.16363889]

# %%
imp.reload(subs)

TEC_DAug, STEC_DAug, RM_DAug, t_hrs_DAug, el_DAug, az_DAug = subs.read_in_fitted_models_CHIME(DRAO_data_Aug2021)
TEC_DJan, STEC_DJan, RM_DJan, t_hrs_DJan, el_DJan, az_DJan = subs.read_in_fitted_models_CHIME(DRAO_data_Jan2021)
TEC_AJan, STEC_AJan, RM_AJan, t_hrs_AJan, el_AJan, az_AJan = subs.read_in_fitted_models_CHIME(Allenby_data_Jan2021)
# Out:
# 31240
# ' \n'
# ['reference', 'time', 'for', 'rel_time=0:', 'year,month,day,hr,min,sec', '2017', '8', '22', '0', '0', '0.0']
#
# 31240
# ' \n'
# ['reference', 'time', 'for', 'rel_time=0:', 'year,month,day,hr,min,sec', '2021', '1', '22', '0', '0', '0.0']

# %%
for i in range(0,31240):
    print(t_hrs_DAug[i],el_DAug[i],az_DAug[i],STEC_DAug[i])
# Out:
# -7.083333333333333 5.001964705570132 0.0025779854691684295 24.122837449370582
# -7.083333333333333 10.002365327291399 0.002608091409968943 19.470700274667234
# -7.083333333333333 15.002747862741117 0.002659378210157361 17.334630094726347
# -7.083333333333333 20.00310940046909 0.00273392992873874 15.62139921470887
# -7.083333333333333 25.00344718882086 0.002834954970731762 14.194837168110586
# -7.083333333333333 30.003758656886152 0.002967146510958852 13.077628687826769
# -7.083333333333333 35.004041434115315 0.0031372680696457635 12.233456695339255
# -7.083333333333333 40.004293368705156 0.0033551129561124812 11.581365449041739
# -7.083333333333333 45.00451254865339 0.0036351137166767606 11.08331269000346
# -7.083333333333333 50.00469769714751 0.003998340252982639 10.705884082460402
# -7.083333333333333 55.00484619271988 0.0044822493520285545 10.42793646372289
# -7.083333333333333 60.00495812260635 0.005142315388972462 10.23692813481432
# ...

# %%
d_el = 2.5
d_az = 0.1
el_pick = 60.
az_pick = 0. # 0 is N, 180 is S

wDJan = np.where( (abs(el_DJan-el_pick)<d_el) & (abs(az_DJan-az_pick)<d_az) )
print(el_DJan[wDJan].shape)

wAJan = np.where( (abs(el_AJan-el_pick)<d_el) & (abs(az_AJan-az_pick)<d_az) )
print(el_AJan[wAJan].shape)
# Out:
# (867,)

# %%
fs = 14

fig = plt.figure(figsize=(15,8))    

plt.scatter(t_hrs_DJan[wDJan],TEC_DJan[wDJan],s=40,color='C0',label='DRAO')
plt.scatter(t_hrs_AJan[wAJan],TEC_DJan[wAJan],s=40,color='C1',label='Allenby')

plt.plot(t_hrs_DJan[wDJan],TEC_DJan[wDJan],color='C0')
plt.plot(t_hrs_AJan[wAJan],TEC_AJan[wAJan],color='C1')

plt.xlim(-7,65)
plt.grid()
plt.legend(fontsize=fs)
#plt.xlim(0,48)
plt.xlabel('Local Time',fontsize=fs)
plt.ylabel('STEC',fontsize=fs)
plt.yticks(fontsize=fs)
#plt.title('February 15 to 16, 2021')
#plt.xticks(ticks=[-6,0,6,12,18,24,30,36,42,48,54,60], 
#           labels=['18:00','00:00','6:00','12:00','18:00','00:00','6:00','12:00','18:00','00:00','6:00','12:00'],
#           fontsize=fs)
# Out:
# (array([-5. , -2.5,  0. ,  2.5,  5. ,  7.5, 10. , 12.5, 15. , 17.5]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
